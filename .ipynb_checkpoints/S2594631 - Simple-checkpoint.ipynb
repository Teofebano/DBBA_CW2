# %% [markdown]
# # Library

# %%
# Installation
# %pip install --quiet mesa
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import
import mesa
import numpy as np
import pandas as pd

import math
import random

# %% [markdown]
# # Class Definition

# %% [markdown]
# ## Agent

# %%
class ChartistAgent(mesa.Agent):
    def __init__(self, id, model, fiat_owned, bitcoin_owned, chartist_day_reference):
        super().__init__(id, model)

        # Attribute Initialization         
        self.fiat = fiat_owned
        self.bitcoin = bitcoin_owned
        self.is_close = True
        self.n = chartist_day_reference
        
        # Default Rule : EMA for both opening and closing
        self.is_open_sma_high = False
        self.is_close_sma_high = False
        
        if (np.random.uniform() <= 0.25):
            # Rule : SMA for both opening and closing             
            self.is_open_sma_high = True
            self.is_close_sma_high = True
        elif (np.random.uniform() > 0.25 and np.random.uniform() < 0.5):
            # Rule : SMA for opening and EMA for closing
            self.is_open_sma_high = True
        elif (np.random.uniform() > 0.25 and np.random.uniform() < 0.75):
            # Rule : EMA for opening and SMA for closing
            self.is_close_sma_high = True
    
    def step(self):
        if self.is_close:
            # Potential Buy
            sma_value = self.calculate_sma_n_days()
            ema_value = self.calculate_ema_n_days()
            
            # Count Probability to Buy Based on Rule
            probability_to_buy = 0
            if self.model.price < sma_value:
                probability_to_buy += (0.8 if self.is_open_filtering_high else 0.2)
            
            if self.model.price > ema_value:
                probability_to_buy += (0.8 if not self.is_open_filtering_high else 0.2)
                
            print(f'{self.unique_id} : {self.is_open_sma_high} {self.is_close_sma_high}')
            print(f'sma value : {sma_value}, ema value : {ema_value}')
            print(f'price : {self.model.price}')
            print(f'prob : {probability_to_buy}')
            
            # Actual Buy
            if (np.random.uniform() <= probability_to_buy):
                self.is_close = False
                
                print('PREVIOUS STATE')
                print(f'bitcoin : {self.bitcoin}')
                print(f'fiat : {self.fiat}')
                
                bitcoin_obtained = math.floor((self.fiat / self.model.price) * 10000) / 10000
                self.bitcoin += bitcoin_obtained
                self.fiat -= self.bitcoin * self.model.price
                self.model.demand += bitcoin_obtained

                print('AFTER STATE')
                print(f'bitcoin : {self.bitcoin}')
                print(f'fiat : {self.fiat}')
    
        else:
            # Potential Sell
            sma_value = self.calculate_sma_n_days()
            ema_value = self.calculate_ema_n_days()

            # Count Probability to Sell Based on Rule
            probability_to_sell = 0
            if self.model.price > sma_value:
                probability_to_sell += (0.8 if self.is_close_filtering_high else 0.2)
            
            if self.model.price < ema_value:
                probability_to_sell += (0.8 if not self.is_close_filtering_high else 0.2)
        
            print(f'{self.unique_id} : {self.is_open_sma_high} {self.is_close_sma_high}')
            print(f'sma value : {sma_value}, ema value : {ema_value}')
            print(f'price : {self.model.price}')
            print(f'prob : {probability_to_buy}')
            
            # Actual Sell
            if (np.random.uniform() <= probability_to_sell):
                self.is_close = True
                
                print('PREVIOUS STATE')
                print(f'bitcoin : {self.bitcoin}')
                print(f'fiat : {self.fiat}')
                
                bitcoin_released = self.bitcoin
                self.fiat += self.bitcoin * self.model.price
                self.bitcoin -= bitcoin_released
                self.model.supply += bitcoin_released
                
                print('AFTER STATE')
                print(f'bitcoin : {self.bitcoin}')
                print(f'fiat : {self.fiat}')
                    
    # Agent Helper Function
    # SMA Rule
    def calculate_sma_n_days(self):
        start_index = max(0, len(self.model.price_history) - self.n)
        window = self.model.price_history[start_index:len(self.model.price_history)]

        return sum(window) / len(window)

    # EMA Rule
    def calculate_ema_n_days(self):
        smooth_factor = 2 / (self.n + 1)
        ema = [self.model.price_history[0]]

        for i in range(1, len(self.model.price_history)):
            value = smooth_factor * self.model.price_history[i] + (1 - smooth_factor) * ema[i-1]
            ema.append(value)

        return ema[len(ema)-1]

# %%
class RandomAgent(mesa.Agent):
    def __init__(self, id, model, fiat_owned, bitcoin_owned):
        super().__init__(id, model)

        # Attribute Initialization         
        self.fiat = fiat_owned
        self.bitcoin = bitcoin_owned
        self.is_close = True
    
    def step(self):
        print(f'{self.unique_id}')

        if self.is_close:
            # Actual Buy
            if (random.choice([True, False])):
                self.is_close = False

                print(f'BUY')
                print('PREVIOUS STATE')
                print(f'bitcoin : {self.bitcoin}')
                print(f'fiat : {self.fiat}')

                bitcoin_obtained = math.floor((self.fiat / self.model.price) * 10000) / 10000
                self.bitcoin += bitcoin_obtained
                self.fiat -= self.bitcoin * self.model.price
                self.model.demand += bitcoin_obtained
                
                print('AFTER STATE')
                print(f'bitcoin : {self.bitcoin}')
                print(f'fiat : {self.fiat}')
    
        else:
            # Actual Sell
            if (random.choice([True, False])):
                self.is_close = True
                
                print(f'SELL')
                print('PREVIOUS STATE')
                print(f'bitcoin : {self.bitcoin}')
                print(f'fiat : {self.fiat}')
                
                bitcoin_released = self.bitcoin
                self.fiat += self.bitcoin * self.model.price
                self.bitcoin -= bitcoin_released
                self.model.supply += bitcoin_released
                
                print('AFTER STATE')
                print(f'bitcoin : {self.bitcoin}')
                print(f'fiat : {self.fiat}')

# %%
import random

class BitcoinMarketModel(mesa.Model):
    def __init__(self, price_start, number_of_agents, total_fiat, total_bitcoin, chartist_ratio, chartist_day_reference):
        self.schedule = mesa.time.RandomActivation(self)
        
        self.price = price_start
        self.price_history = [price_start]
        self.number_of_agents = number_of_agents
        
        self.total_fiat = total_fiat
        self.total_bitcoin = total_bitcoin
        self.supply = 0
        self.demand = 0

        for i in range(self.number_of_agents):
            fiat_owned = self.total_fiat / self.number_of_agents
            bitcoin_owned = 0
            
            if (np.random.uniform() <= chartist_ratio):
                a = ChartistAgent(str(f"chartist-{i}"), 
                              self, 
                              fiat_owned,
                              bitcoin_owned, 
                              chartist_day_reference)

                self.schedule.add(a)
            else:
                a = RandomAgent(str(f"random-{i}"), 
                              self, 
                              fiat_owned,
                              bitcoin_owned)

                self.schedule.add(a)
    
    def step(self):
        # Before Stepping
#         print('NEW CYCLE')
        self.price += self.calculate_today_price_change()
        self.supply = 0
        self.demand = 0
        
        # Stepping
        self.schedule.step()
        
        # After Stepping
        self.price_history.append(self.price)

        
    # Model Helper Function
    # Calculate Price
    def calculate_today_price_change(self):
#         print('NEW PRICE')
        supply_demand_difference = self.demand - self.supply
        sign = math.copysign(1, supply_demand_difference)
        
        return math.floor((math.sqrt(2) / 2) *  sign * math.sqrt(abs(supply_demand_difference)))
    
    # Calculate New Bitcoin Introduced to Model
    def calculate_new_bitcoin(self):
        return 0.6 * self.total_bitcoin

# %% [markdown]
# # SIMULATION

# %%
total_bitcoin = 10000
total_fiat = 5000000

# Agents Parameters
number_of_agents = 4200 # In 2020, there are 420M users
chartist_day_reference = 3
chartist_ratio = 0.6

price_start = 5614

model = BitcoinMarketModel(price_start, 
                           number_of_agents, 
                           total_fiat, 
                           total_bitcoin, 
                           chartist_ratio, 
                           chartist_day_reference)

for i in range(1399):
    print(f'progress : {i}/1399')
    model.step()
    
agents = model.schedule.agents
sum_fiat = 0
sum_bitcoin = 0
count_open = 0

sum_chartist_fiat = 0
sum_chartist_bitcoin = 0
count_chartist_open = 0
count_chartist_agent = 0

sum_chartist_R1R1_fiat = 0
sum_chartist_R1R1_bitcoin = 0
count_chartist_R1R1_open = 0
count_chartist_R1R1_agent = 0

sum_chartist_R2R1_fiat = 0
sum_chartist_R2R1_bitcoin = 0
count_chartist_R2R1_open = 0
count_chartist_R2R1_agent = 0

sum_chartist_R1R2_fiat = 0
sum_chartist_R1R2_bitcoin = 0
count_chartist_R1R2_open = 0
count_chartist_R1R2_agent = 0

sum_chartist_R2R2_fiat = 0
sum_chartist_R2R2_bitcoin = 0
count_chartist_R2R2_open = 0
count_chartist_R2R2_agent = 0

sum_random_fiat = 0
sum_random_bitcoin = 0
count_random_open = 0

for a in agents:
    sum_fiat += a.fiat
    sum_bitcoin += a.bitcoin
    if a.bitcoin > 0:
        count_open += 1
        
    if 'chartist' in a.unique_id:
        sum_chartist_fiat += a.fiat
        sum_chartist_bitcoin += a.bitcoin
        count_chartist_agent += 1
        
        if a.bitcoin > 0:
            count_chartist_open += 1
        
        if a.is_open_filtering_high and a.is_close_filtering_high:
            sum_chartist_R1R1_fiat += a.fiat
            sum_chartist_R1R1_bitcoin += a.bitcoin
            count_chartist_R1R1_agent += 1

            if a.bitcoin > 0:
                count_chartist_R1R1_open += 1
        
        if a.is_open_filtering_high and not a.is_close_filtering_high:
            sum_chartist_R1R2_fiat += a.fiat
            sum_chartist_R1R2_bitcoin += a.bitcoin
            count_chartist_R1R2_agent += 1

            if a.bitcoin > 0:
                count_chartist_R1R2_open += 1
                
        if not a.is_open_filtering_high and a.is_close_filtering_high:
            sum_chartist_R2R1_fiat += a.fiat
            sum_chartist_R2R1_bitcoin += a.bitcoin
            count_chartist_R2R1_agent += 1

            if a.bitcoin > 0:
                count_chartist_R2R1_open += 1
        
        if not a.is_open_filtering_high and not a.is_close_filtering_high:
            sum_chartist_R2R2_fiat += a.fiat
            sum_chartist_R2R2_bitcoin += a.bitcoin
            count_chartist_R2R2_agent += 1

            if a.bitcoin > 0:
                count_chartist_R2R2_open += 1
            
    
    if 'random' in a.unique_id:
        sum_random_fiat += a.fiat
        sum_random_bitcoin += a.bitcoin
        if a.bitcoin > 0:
            count_random_open += 1

price = model.price
bitcoin_value = sum_bitcoin * price
total_valuation = sum_fiat + bitcoin_value
print(f"Sum Fiat {sum_fiat}")
print(f"Sum Bitcoin {sum_bitcoin}")
print(f"Value Bitcoin {bitcoin_value}")
print(f"Total Valuation {total_valuation}")
print(f"Count Open {count_open}")

chartist_bitcoin_value = sum_chartist_bitcoin * price
total_valuation_chartist = sum_chartist_fiat + chartist_bitcoin_value
print(f"Sum Chartist Fiat {sum_chartist_fiat}")
print(f"Sum Chartist Bitcoin {sum_chartist_bitcoin}")
print(f"Value Chartist Bitcoin {chartist_bitcoin_value}")
print(f"Total Chartist Valuation {total_valuation_chartist}")
print(f"Count Chartist Open {count_chartist_open}")

chartist_R1R1_bitcoin_value = sum_chartist_R1R1_bitcoin * price
total_valuation_chartist_R1R1 = sum_chartist_R1R1_fiat + chartist_R1R1_bitcoin_value
print(f"Sum Chartist R1R1 Fiat {sum_chartist_R1R1_fiat}")
print(f"Sum Chartist R1R1 Bitcoin {sum_chartist_R1R1_bitcoin}")
print(f"Value Chartist R1R1 Bitcoin {chartist_R1R1_bitcoin_value}")
print(f"Total Chartist R1R1 Valuation {total_valuation_chartist_R1R1}")
print(f"Count Chartist R1R1 Open {count_chartist_R1R1_open}")

chartist_R1R2_bitcoin_value = sum_chartist_R1R2_bitcoin * price
total_valuation_chartist_R1R2 = sum_chartist_R1R2_fiat + chartist_R1R2_bitcoin_value
print(f"Sum Chartist R1R2 Fiat {sum_chartist_R1R2_fiat}")
print(f"Sum Chartist R1R2 Bitcoin {sum_chartist_R1R2_bitcoin}")
print(f"Value Chartist R1R2 Bitcoin {chartist_R1R2_bitcoin_value}")
print(f"Total Chartist R1R2 Valuation {total_valuation_chartist_R1R2}")
print(f"Count Chartist R1R2 Open {count_chartist_R1R2_open}")

chartist_R2R1_bitcoin_value = sum_chartist_R2R1_bitcoin * price
total_valuation_chartist_R2R1 = sum_chartist_R2R1_fiat + chartist_R2R1_bitcoin_value
print(f"Sum Chartist R2R1 Fiat {sum_chartist_R2R1_fiat}")
print(f"Sum Chartist R2R1 Bitcoin {sum_chartist_R2R1_bitcoin}")
print(f"Value Chartist R2R1 Bitcoin {chartist_R2R1_bitcoin_value}")
print(f"Total Chartist R2R1 Valuation {total_valuation_chartist_R2R1}")
print(f"Count Chartist R2R1 Open {count_chartist_R2R1_open}")

chartist_R2R2_bitcoin_value = sum_chartist_R2R2_bitcoin * price
total_valuation_chartist_R2R2 = sum_chartist_R2R2_fiat + chartist_R2R2_bitcoin_value
print(f"Sum Chartist R2R2 Fiat {sum_chartist_R2R2_fiat}")
print(f"Sum Chartist R2R2 Bitcoin {sum_chartist_R2R2_bitcoin}")
print(f"Value Chartist R2R2 Bitcoin {chartist_R2R2_bitcoin_value}")
print(f"Total Chartist R2R2 Valuation {total_valuation_chartist_R2R2}")
print(f"Count Chartist R2R2 Open {count_chartist_R2R2_open}")

random_bitcoin_value = sum_random_bitcoin * price
total_valuation_random = sum_random_fiat + random_bitcoin_value
print(f"Sum Random Fiat {sum_random_fiat}")
print(f"Sum Random Bitcoin {sum_random_bitcoin}")
print(f"Value Random Bitcoin {random_bitcoin_value}")
print(f"Total Random Valuation {total_valuation_random}")
print(f"Count Random Open {count_random_open}")

print(f"NUMBER OF CHARTIST : {count_chartist_agent}")
print(f"Chartist vs All Proportion Fiat : {sum_chartist_fiat / sum_fiat  * 100}")
print(f"Chartist vs All Proportion Bitcoin : {sum_chartist_bitcoin / sum_bitcoin  * 100}")
print(f"Chartist vs All Proportion Total Valuation : {total_valuation_chartist / total_valuation  * 100}")

print(f"NUMBER OF CHARTIST R1R1 : {count_chartist_R1R1_agent}")
print(f"Chartist R1R1 vs Chartist All Proportion Fiat : {sum_chartist_R1R1_fiat / sum_chartist_fiat  * 100}")
print(f"Chartist R1R1 vs Chartist All Proportion Bitcoin : {sum_chartist_R1R1_bitcoin / sum_chartist_bitcoin  * 100}")
print(f"Chartist R1R1 vs Chartist All Proportion Total Valuation : {total_valuation_chartist_R1R1 / total_valuation_chartist  * 100}")

print(f"NUMBER OF CHARTIST R1R1 : {count_chartist_R1R2_agent}")
print(f"Chartist R1R2 vs Chartist All Proportion Fiat : {sum_chartist_R1R2_fiat / sum_chartist_fiat  * 100}")
print(f"Chartist R1R2 vs Chartist All Proportion Bitcoin : {sum_chartist_R1R2_bitcoin / sum_chartist_bitcoin  * 100}")
print(f"Chartist R1R2 vs Chartist All Proportion Total Valuation : {total_valuation_chartist_R1R2 / total_valuation_chartist  * 100}")

print(f"NUMBER OF CHARTIST R1R1 : {count_chartist_R2R1_agent}")
print(f"Chartist R2R1 vs Chartist All Proportion Fiat : {sum_chartist_R2R1_fiat / sum_chartist_fiat  * 100}")
print(f"Chartist R2R1 vs Chartist All Proportion Bitcoin : {sum_chartist_R2R1_bitcoin / sum_chartist_bitcoin  * 100}")
print(f"Chartist R2R1 vs Chartist All Proportion Total Valuation : {total_valuation_chartist_R2R1 / total_valuation_chartist  * 100}")

print(f"NUMBER OF CHARTIST R1R1 : {count_chartist_R2R2_agent}")
print(f"Chartist R2R2 vs Chartist All Proportion Fiat : {sum_chartist_R2R2_fiat / sum_chartist_fiat  * 100}")
print(f"Chartist R2R2 vs Chartist All Proportion Bitcoin : {sum_chartist_R2R2_bitcoin / sum_chartist_bitcoin  * 100}")
print(f"Chartist R2R2 vs Chartist All Proportion Total Valuation : {total_valuation_chartist_R2R2 / total_valuation_chartist  * 100}")
# Out:
# progress : 0/1399
# progress : 1/1399
# progress : 2/1399
# progress : 3/1399
# progress : 4/1399
# progress : 5/1399
# progress : 6/1399
# progress : 7/1399
# progress : 8/1399
# progress : 9/1399
# progress : 10/1399
# progress : 11/1399
# progress : 12/1399
# progress : 13/1399
# progress : 14/1399
# progress : 15/1399
# progress : 16/1399
# progress : 17/1399
# progress : 18/1399
# progress : 19/1399
# progress : 20/1399
# progress : 21/1399
# progress : 22/1399
# progress : 23/1399
# progress : 24/1399
# progress : 25/1399
# progress : 26/1399
# progress : 27/1399
# progress : 28/1399
# progress : 29/1399
# progress : 30/1399
# progress : 31/1399
# progress : 32/1399
# progress : 33/1399
# progress : 34/1399
# progress : 35/1399
# progress : 36/1399
# progress : 37/1399
# progress : 38/1399
# progress : 39/1399
# progress : 40/1399
# progress : 41/1399
# progress : 42/1399
# progress : 43/1399
# progress : 44/1399
# progress : 45/1399
# progress : 46/1399
# progress : 47/1399
# progress : 48/1399
# progress : 49/1399
# progress : 50/1399
# progress : 51/1399
# progress : 52/1399
# progress : 53/1399
# progress : 54/1399
# progress : 55/1399
# progress : 56/1399
# progress : 57/1399
# progress : 58/1399
# progress : 59/1399
# progress : 60/1399
# progress : 61/1399
# progress : 62/1399
# progress : 63/1399
# progress : 64/1399
# progress : 65/1399
# progress : 66/1399
# progress : 67/1399
# progress : 68/1399
# progress : 69/1399
# progress : 70/1399
# progress : 71/1399
# progress : 72/1399
# progress : 73/1399
# progress : 74/1399
# progress : 75/1399
# progress : 76/1399
# progress : 77/1399
# progress : 78/1399
# progress : 79/1399
# progress : 80/1399
# progress : 81/1399
# progress : 82/1399
# progress : 83/1399
# progress : 84/1399
# progress : 85/1399
# progress : 86/1399
# progress : 87/1399
# progress : 88/1399
# progress : 89/1399
# progress : 90/1399
# progress : 91/1399
# progress : 92/1399
# progress : 93/1399
# progress : 94/1399
# progress : 95/1399
# progress : 96/1399
# progress : 97/1399
# progress : 98/1399
# progress : 99/1399
# progress : 100/1399
# progress : 101/1399
# progress : 102/1399
# progress : 103/1399
# progress : 104/1399
# progress : 105/1399
# progress : 106/1399
# progress : 107/1399
# progress : 108/1399
# progress : 109/1399
# progress : 110/1399
# progress : 111/1399
# progress : 112/1399
# progress : 113/1399
# progress : 114/1399
# progress : 115/1399
# progress : 116/1399
# progress : 117/1399
# progress : 118/1399
# progress : 119/1399
# progress : 120/1399
# progress : 121/1399
# progress : 122/1399
# progress : 123/1399
# progress : 124/1399
# progress : 125/1399
# progress : 126/1399
# progress : 127/1399
# progress : 128/1399
# progress : 129/1399
# progress : 130/1399
# progress : 131/1399
# progress : 132/1399
# progress : 133/1399
# progress : 134/1399
# progress : 135/1399
# progress : 136/1399
# progress : 137/1399
# progress : 138/1399
# progress : 139/1399
# progress : 140/1399
# progress : 141/1399
# progress : 142/1399
# progress : 143/1399
# progress : 144/1399
# progress : 145/1399
# progress : 146/1399
# progress : 147/1399
# progress : 148/1399
# progress : 149/1399
# progress : 150/1399
# progress : 151/1399
# progress : 152/1399
# progress : 153/1399
# progress : 154/1399
# progress : 155/1399
# progress : 156/1399
# progress : 157/1399
# progress : 158/1399
# progress : 159/1399
# progress : 160/1399
# progress : 161/1399
# progress : 162/1399
# progress : 163/1399
# progress : 164/1399
# progress : 165/1399
# progress : 166/1399
# progress : 167/1399
# progress : 168/1399
# progress : 169/1399
# progress : 170/1399
# progress : 171/1399
# progress : 172/1399
# progress : 173/1399
# progress : 174/1399
# progress : 175/1399
# progress : 176/1399
# progress : 177/1399
# progress : 178/1399
# progress : 179/1399
# progress : 180/1399
# progress : 181/1399
# progress : 182/1399
# progress : 183/1399
# progress : 184/1399
# progress : 185/1399
# progress : 186/1399
# progress : 187/1399
# progress : 188/1399
# progress : 189/1399
# progress : 190/1399
# progress : 191/1399
# progress : 192/1399
# progress : 193/1399
# progress : 194/1399
# progress : 195/1399
# progress : 196/1399
# progress : 197/1399
# progress : 198/1399
# progress : 199/1399
# progress : 200/1399
# progress : 201/1399
# progress : 202/1399
# progress : 203/1399
# progress : 204/1399
# progress : 205/1399
# progress : 206/1399
# progress : 207/1399
# progress : 208/1399
# progress : 209/1399
# progress : 210/1399
# progress : 211/1399
# progress : 212/1399
# progress : 213/1399
# progress : 214/1399
# progress : 215/1399
# progress : 216/1399
# progress : 217/1399
# progress : 218/1399
# progress : 219/1399
# progress : 220/1399
# progress : 221/1399
# progress : 222/1399
# progress : 223/1399
# progress : 224/1399
# progress : 225/1399
# progress : 226/1399
# progress : 227/1399
# progress : 228/1399
# progress : 229/1399
# progress : 230/1399
# progress : 231/1399
# progress : 232/1399
# progress : 233/1399
# progress : 234/1399
# progress : 235/1399
# progress : 236/1399
# progress : 237/1399
# progress : 238/1399
# progress : 239/1399
# progress : 240/1399
# progress : 241/1399
# progress : 242/1399
# progress : 243/1399
# progress : 244/1399
# progress : 245/1399
# progress : 246/1399
# progress : 247/1399
# progress : 248/1399
# progress : 249/1399
# progress : 250/1399
# progress : 251/1399
# progress : 252/1399
# progress : 253/1399
# progress : 254/1399
# progress : 255/1399
# progress : 256/1399
# progress : 257/1399
# progress : 258/1399
# progress : 259/1399
# progress : 260/1399
# progress : 261/1399
# progress : 262/1399
# progress : 263/1399
# progress : 264/1399
# progress : 265/1399
# progress : 266/1399
# progress : 267/1399
# progress : 268/1399
# progress : 269/1399
# progress : 270/1399
# progress : 271/1399
# progress : 272/1399
# progress : 273/1399
# progress : 274/1399
# progress : 275/1399
# progress : 276/1399
# progress : 277/1399
# progress : 278/1399
# progress : 279/1399
# progress : 280/1399
# progress : 281/1399
# progress : 282/1399
# progress : 283/1399
# progress : 284/1399
# progress : 285/1399
# progress : 286/1399
# progress : 287/1399
# progress : 288/1399
# progress : 289/1399
# progress : 290/1399
# progress : 291/1399
# progress : 292/1399
# progress : 293/1399
# progress : 294/1399
# progress : 295/1399
# progress : 296/1399
# progress : 297/1399
# progress : 298/1399
# progress : 299/1399
# progress : 300/1399
# progress : 301/1399
# progress : 302/1399
# progress : 303/1399
# progress : 304/1399
# progress : 305/1399
# progress : 306/1399
# progress : 307/1399
# progress : 308/1399
# progress : 309/1399
# progress : 310/1399
# progress : 311/1399
# progress : 312/1399
# progress : 313/1399
# progress : 314/1399
# progress : 315/1399
# progress : 316/1399
# progress : 317/1399
# progress : 318/1399
# progress : 319/1399
# progress : 320/1399
# progress : 321/1399
# progress : 322/1399
# progress : 323/1399
# progress : 324/1399
# progress : 325/1399
# progress : 326/1399
# progress : 327/1399
# progress : 328/1399
# progress : 329/1399
# progress : 330/1399
# progress : 331/1399
# progress : 332/1399
# progress : 333/1399
# progress : 334/1399
# progress : 335/1399
# progress : 336/1399
# progress : 337/1399
# progress : 338/1399
# progress : 339/1399
# progress : 340/1399
# progress : 341/1399
# progress : 342/1399
# progress : 343/1399
# progress : 344/1399
# progress : 345/1399
# progress : 346/1399
# progress : 347/1399
# progress : 348/1399
# progress : 349/1399
# progress : 350/1399
# progress : 351/1399
# progress : 352/1399
# progress : 353/1399
# progress : 354/1399
# progress : 355/1399
# progress : 356/1399
# progress : 357/1399
# progress : 358/1399
# progress : 359/1399
# progress : 360/1399
# progress : 361/1399
# progress : 362/1399
# progress : 363/1399
# progress : 364/1399
# progress : 365/1399
# progress : 366/1399
# progress : 367/1399
# progress : 368/1399
# progress : 369/1399
# progress : 370/1399
# progress : 371/1399
# progress : 372/1399
# progress : 373/1399
# progress : 374/1399
# progress : 375/1399
# progress : 376/1399
# progress : 377/1399
# progress : 378/1399
# progress : 379/1399
# progress : 380/1399
# progress : 381/1399
# progress : 382/1399
# progress : 383/1399
# progress : 384/1399
# progress : 385/1399
# progress : 386/1399
# progress : 387/1399
# progress : 388/1399
# progress : 389/1399
# progress : 390/1399
# progress : 391/1399
# progress : 392/1399
# progress : 393/1399
# progress : 394/1399
# progress : 395/1399
# progress : 396/1399
# progress : 397/1399
# progress : 398/1399
# progress : 399/1399
# progress : 400/1399
# progress : 401/1399
# progress : 402/1399
# progress : 403/1399
# progress : 404/1399
# progress : 405/1399
# progress : 406/1399
# progress : 407/1399
# progress : 408/1399
# progress : 409/1399
# progress : 410/1399
# progress : 411/1399
# progress : 412/1399
# progress : 413/1399
# progress : 414/1399
# progress : 415/1399
# progress : 416/1399
# progress : 417/1399
# progress : 418/1399
# progress : 419/1399
# progress : 420/1399
# progress : 421/1399
# progress : 422/1399
# progress : 423/1399
# progress : 424/1399
# progress : 425/1399
# progress : 426/1399
# progress : 427/1399
# progress : 428/1399
# progress : 429/1399
# progress : 430/1399
# progress : 431/1399
# progress : 432/1399
# progress : 433/1399
# progress : 434/1399
# progress : 435/1399
# progress : 436/1399
# progress : 437/1399
# progress : 438/1399
# progress : 439/1399
# progress : 440/1399
# progress : 441/1399
# progress : 442/1399
# progress : 443/1399
# progress : 444/1399
# progress : 445/1399
# progress : 446/1399
# progress : 447/1399
# progress : 448/1399
# progress : 449/1399
# progress : 450/1399
# progress : 451/1399
# progress : 452/1399
# progress : 453/1399
# progress : 454/1399
# progress : 455/1399
# progress : 456/1399
# progress : 457/1399
# progress : 458/1399
# progress : 459/1399
# progress : 460/1399
# progress : 461/1399
# progress : 462/1399
# progress : 463/1399
# progress : 464/1399
# progress : 465/1399
# progress : 466/1399
# progress : 467/1399
# progress : 468/1399
# progress : 469/1399
# progress : 470/1399
# progress : 471/1399
# progress : 472/1399
# progress : 473/1399
# progress : 474/1399
# progress : 475/1399
# progress : 476/1399
# progress : 477/1399
# progress : 478/1399
# progress : 479/1399
# progress : 480/1399
# progress : 481/1399
# progress : 482/1399
# progress : 483/1399
# progress : 484/1399
# progress : 485/1399
# progress : 486/1399
# progress : 487/1399
# progress : 488/1399
# progress : 489/1399
# progress : 490/1399
# progress : 491/1399
# progress : 492/1399
# progress : 493/1399
# progress : 494/1399
# progress : 495/1399
# progress : 496/1399
# progress : 497/1399
# progress : 498/1399
# progress : 499/1399
# progress : 500/1399
# progress : 501/1399
# progress : 502/1399
# progress : 503/1399
# progress : 504/1399
# progress : 505/1399
# progress : 506/1399
# progress : 507/1399
# progress : 508/1399
# progress : 509/1399
# progress : 510/1399
# progress : 511/1399
# progress : 512/1399
# progress : 513/1399
# progress : 514/1399
# progress : 515/1399
# progress : 516/1399
# progress : 517/1399
# progress : 518/1399
# progress : 519/1399
# progress : 520/1399
# progress : 521/1399
# progress : 522/1399
# progress : 523/1399
# progress : 524/1399
# progress : 525/1399
# progress : 526/1399
# progress : 527/1399
# progress : 528/1399
# progress : 529/1399
# progress : 530/1399
# progress : 531/1399
# progress : 532/1399
# progress : 533/1399
# progress : 534/1399
# progress : 535/1399
# progress : 536/1399
# progress : 537/1399
# progress : 538/1399
# progress : 539/1399
# progress : 540/1399
# progress : 541/1399
# progress : 542/1399
# progress : 543/1399
# progress : 544/1399
# progress : 545/1399
# progress : 546/1399
# progress : 547/1399
# progress : 548/1399
# progress : 549/1399
# progress : 550/1399
# progress : 551/1399
# progress : 552/1399
# progress : 553/1399
# progress : 554/1399
# progress : 555/1399
# progress : 556/1399
# progress : 557/1399
# progress : 558/1399
# progress : 559/1399
# progress : 560/1399
# progress : 561/1399
# progress : 562/1399
# progress : 563/1399
# progress : 564/1399
# progress : 565/1399
# progress : 566/1399
# progress : 567/1399
# progress : 568/1399
# progress : 569/1399
# progress : 570/1399
# progress : 571/1399
# progress : 572/1399
# progress : 573/1399
# progress : 574/1399
# progress : 575/1399
# progress : 576/1399
# progress : 577/1399
# progress : 578/1399
# progress : 579/1399
# progress : 580/1399
# progress : 581/1399
# progress : 582/1399
# progress : 583/1399
# progress : 584/1399
# progress : 585/1399
# progress : 586/1399
# progress : 587/1399
# progress : 588/1399
# progress : 589/1399
# progress : 590/1399
# progress : 591/1399
# progress : 592/1399
# progress : 593/1399
# progress : 594/1399
# progress : 595/1399
# progress : 596/1399
# progress : 597/1399
# progress : 598/1399
# progress : 599/1399
# progress : 600/1399
# progress : 601/1399
# progress : 602/1399
# progress : 603/1399
# progress : 604/1399
# progress : 605/1399
# progress : 606/1399
# progress : 607/1399
# progress : 608/1399
# progress : 609/1399
# progress : 610/1399
# progress : 611/1399
# progress : 612/1399
# progress : 613/1399
# progress : 614/1399
# progress : 615/1399
# progress : 616/1399
# progress : 617/1399
# progress : 618/1399
# progress : 619/1399
# progress : 620/1399
# progress : 621/1399
# progress : 622/1399
# progress : 623/1399
# progress : 624/1399
# progress : 625/1399
# progress : 626/1399
# progress : 627/1399
# progress : 628/1399
# progress : 629/1399
# progress : 630/1399
# progress : 631/1399
# progress : 632/1399
# progress : 633/1399
# progress : 634/1399
# progress : 635/1399
# progress : 636/1399
# progress : 637/1399
# progress : 638/1399
# progress : 639/1399
# progress : 640/1399
# progress : 641/1399
# progress : 642/1399
# progress : 643/1399
# progress : 644/1399
# progress : 645/1399
# progress : 646/1399
# progress : 647/1399
# progress : 648/1399
# progress : 649/1399
# progress : 650/1399
# progress : 651/1399
# progress : 652/1399
# progress : 653/1399
# progress : 654/1399
# progress : 655/1399
# progress : 656/1399
# progress : 657/1399
# progress : 658/1399
# progress : 659/1399
# progress : 660/1399
# progress : 661/1399
# progress : 662/1399
# progress : 663/1399
# progress : 664/1399
# progress : 665/1399
# progress : 666/1399
# progress : 667/1399
# progress : 668/1399
# progress : 669/1399
# progress : 670/1399
# progress : 671/1399
# progress : 672/1399
# progress : 673/1399
# progress : 674/1399
# progress : 675/1399
# progress : 676/1399
# progress : 677/1399
# progress : 678/1399
# progress : 679/1399
# progress : 680/1399
# progress : 681/1399
# progress : 682/1399
# progress : 683/1399
# progress : 684/1399
# progress : 685/1399
# progress : 686/1399
# progress : 687/1399
# progress : 688/1399
# progress : 689/1399
# progress : 690/1399
# progress : 691/1399
# progress : 692/1399
# progress : 693/1399
# progress : 694/1399
# progress : 695/1399
# progress : 696/1399
# progress : 697/1399
# progress : 698/1399
# progress : 699/1399
# progress : 700/1399
# progress : 701/1399
# progress : 702/1399
# progress : 703/1399
# progress : 704/1399
# progress : 705/1399
# progress : 706/1399
# progress : 707/1399
# progress : 708/1399
# progress : 709/1399
# progress : 710/1399
# progress : 711/1399
# progress : 712/1399
# progress : 713/1399
# progress : 714/1399
# progress : 715/1399
# progress : 716/1399
# progress : 717/1399
# progress : 718/1399
# progress : 719/1399
# progress : 720/1399
# progress : 721/1399
# progress : 722/1399
# progress : 723/1399
# progress : 724/1399
# progress : 725/1399
# progress : 726/1399
# progress : 727/1399
# progress : 728/1399
# progress : 729/1399
# progress : 730/1399
# progress : 731/1399
# progress : 732/1399
# progress : 733/1399
# progress : 734/1399
# progress : 735/1399
# progress : 736/1399
# progress : 737/1399
# progress : 738/1399
# progress : 739/1399
# progress : 740/1399
# progress : 741/1399
# progress : 742/1399
# progress : 743/1399
# progress : 744/1399
# progress : 745/1399
# progress : 746/1399
# progress : 747/1399
# progress : 748/1399
# progress : 749/1399
# progress : 750/1399
# progress : 751/1399
# progress : 752/1399
# progress : 753/1399
# progress : 754/1399
# progress : 755/1399
# progress : 756/1399
# progress : 757/1399
# progress : 758/1399
# progress : 759/1399
# progress : 760/1399
# progress : 761/1399
# progress : 762/1399
# progress : 763/1399
# progress : 764/1399
# progress : 765/1399
# progress : 766/1399
# progress : 767/1399
# progress : 768/1399
# progress : 769/1399
# progress : 770/1399
# progress : 771/1399
# progress : 772/1399
# progress : 773/1399
# progress : 774/1399
# progress : 775/1399
# progress : 776/1399
# progress : 777/1399
# progress : 778/1399
# progress : 779/1399
# progress : 780/1399
# progress : 781/1399
# progress : 782/1399
# progress : 783/1399
# progress : 784/1399
# progress : 785/1399
# progress : 786/1399
# progress : 787/1399
# progress : 788/1399
# progress : 789/1399
# progress : 790/1399
# progress : 791/1399
# progress : 792/1399
# progress : 793/1399
# progress : 794/1399
# progress : 795/1399
# progress : 796/1399
# progress : 797/1399
# progress : 798/1399
# progress : 799/1399
# progress : 800/1399
# progress : 801/1399
# progress : 802/1399
# progress : 803/1399
# progress : 804/1399
# progress : 805/1399
# progress : 806/1399
# progress : 807/1399
# progress : 808/1399
# progress : 809/1399
# progress : 810/1399
# progress : 811/1399
# progress : 812/1399
# progress : 813/1399
# progress : 814/1399
# progress : 815/1399
# progress : 816/1399
# progress : 817/1399
# progress : 818/1399
# progress : 819/1399
# progress : 820/1399
# progress : 821/1399
# progress : 822/1399
# progress : 823/1399
# progress : 824/1399
# progress : 825/1399
# progress : 826/1399
# progress : 827/1399
# progress : 828/1399
# progress : 829/1399
# progress : 830/1399
# progress : 831/1399
# progress : 832/1399
# progress : 833/1399
# progress : 834/1399
# progress : 835/1399
# progress : 836/1399
# progress : 837/1399
# progress : 838/1399
# progress : 839/1399
# progress : 840/1399
# progress : 841/1399
# progress : 842/1399
# progress : 843/1399
# progress : 844/1399
# progress : 845/1399
# progress : 846/1399
# progress : 847/1399
# progress : 848/1399
# progress : 849/1399
# progress : 850/1399
# progress : 851/1399
# progress : 852/1399
# progress : 853/1399
# progress : 854/1399
# progress : 855/1399
# progress : 856/1399
# progress : 857/1399
# progress : 858/1399
# progress : 859/1399
# progress : 860/1399
# progress : 861/1399
# progress : 862/1399
# progress : 863/1399
# progress : 864/1399
# progress : 865/1399
# progress : 866/1399
# progress : 867/1399
# progress : 868/1399
# progress : 869/1399
# progress : 870/1399
# progress : 871/1399
# progress : 872/1399
# progress : 873/1399
# progress : 874/1399
# progress : 875/1399
# progress : 876/1399
# progress : 877/1399
# progress : 878/1399
# progress : 879/1399
# progress : 880/1399
# progress : 881/1399
# progress : 882/1399
# progress : 883/1399
# progress : 884/1399
# progress : 885/1399
# progress : 886/1399
# progress : 887/1399
# progress : 888/1399
# progress : 889/1399
# progress : 890/1399
# progress : 891/1399
# progress : 892/1399
# progress : 893/1399
# progress : 894/1399
# progress : 895/1399
# progress : 896/1399
# progress : 897/1399
# progress : 898/1399
# progress : 899/1399
# progress : 900/1399
# progress : 901/1399
# progress : 902/1399
# progress : 903/1399
# progress : 904/1399
# progress : 905/1399
# progress : 906/1399
# progress : 907/1399
# progress : 908/1399
# progress : 909/1399
# progress : 910/1399
# progress : 911/1399
# progress : 912/1399
# progress : 913/1399
# progress : 914/1399
# progress : 915/1399
# progress : 916/1399
# progress : 917/1399
# progress : 918/1399
# progress : 919/1399
# progress : 920/1399
# progress : 921/1399
# progress : 922/1399
# progress : 923/1399
# progress : 924/1399
# progress : 925/1399
# progress : 926/1399
# progress : 927/1399
# progress : 928/1399
# progress : 929/1399
# progress : 930/1399
# progress : 931/1399
# progress : 932/1399
# progress : 933/1399
# progress : 934/1399
# progress : 935/1399
# progress : 936/1399
# progress : 937/1399
# progress : 938/1399
# progress : 939/1399
# progress : 940/1399
# progress : 941/1399
# progress : 942/1399
# progress : 943/1399
# progress : 944/1399
# progress : 945/1399
# progress : 946/1399
# progress : 947/1399
# progress : 948/1399
# progress : 949/1399
# progress : 950/1399
# progress : 951/1399
# progress : 952/1399
# progress : 953/1399
# progress : 954/1399
# progress : 955/1399
# progress : 956/1399
# progress : 957/1399
# progress : 958/1399
# progress : 959/1399
# progress : 960/1399
# progress : 961/1399
# progress : 962/1399
# progress : 963/1399
# progress : 964/1399
# progress : 965/1399
# progress : 966/1399
# progress : 967/1399
# progress : 968/1399
# progress : 969/1399
# progress : 970/1399
# progress : 971/1399
# progress : 972/1399
# progress : 973/1399
# progress : 974/1399
# progress : 975/1399
# progress : 976/1399
# progress : 977/1399
# progress : 978/1399
# progress : 979/1399
# progress : 980/1399
# progress : 981/1399
# progress : 982/1399
# progress : 983/1399
# progress : 984/1399
# progress : 985/1399
# progress : 986/1399
# progress : 987/1399
# progress : 988/1399
# progress : 989/1399
# progress : 990/1399
# progress : 991/1399
# progress : 992/1399
# progress : 993/1399
# progress : 994/1399
# progress : 995/1399
# progress : 996/1399
# progress : 997/1399
# progress : 998/1399
# progress : 999/1399
# progress : 1000/1399
# progress : 1001/1399
# progress : 1002/1399
# progress : 1003/1399
# progress : 1004/1399
# progress : 1005/1399
# progress : 1006/1399
# progress : 1007/1399
# progress : 1008/1399
# progress : 1009/1399
# progress : 1010/1399
# progress : 1011/1399
# progress : 1012/1399
# progress : 1013/1399
# progress : 1014/1399
# progress : 1015/1399
# progress : 1016/1399
# progress : 1017/1399
# progress : 1018/1399
# progress : 1019/1399
# progress : 1020/1399
# progress : 1021/1399
# progress : 1022/1399
# progress : 1023/1399
# progress : 1024/1399
# progress : 1025/1399
# progress : 1026/1399
# progress : 1027/1399
# progress : 1028/1399
# progress : 1029/1399
# progress : 1030/1399
# progress : 1031/1399
# progress : 1032/1399
# progress : 1033/1399
# progress : 1034/1399
# progress : 1035/1399
# progress : 1036/1399
# progress : 1037/1399
# progress : 1038/1399
# progress : 1039/1399
# progress : 1040/1399
# progress : 1041/1399
# progress : 1042/1399
# progress : 1043/1399
# progress : 1044/1399
# progress : 1045/1399
# progress : 1046/1399
# progress : 1047/1399
# progress : 1048/1399
# progress : 1049/1399
# progress : 1050/1399
# progress : 1051/1399
# progress : 1052/1399
# progress : 1053/1399
# progress : 1054/1399
# progress : 1055/1399
# progress : 1056/1399
# progress : 1057/1399
# progress : 1058/1399
# progress : 1059/1399
# progress : 1060/1399
# progress : 1061/1399
# progress : 1062/1399
# progress : 1063/1399
# progress : 1064/1399
# progress : 1065/1399
# progress : 1066/1399
# progress : 1067/1399
# progress : 1068/1399
# progress : 1069/1399
# progress : 1070/1399
# progress : 1071/1399
# progress : 1072/1399
# progress : 1073/1399
# progress : 1074/1399
# progress : 1075/1399
# progress : 1076/1399
# progress : 1077/1399
# progress : 1078/1399
# progress : 1079/1399
# progress : 1080/1399
# progress : 1081/1399
# progress : 1082/1399
# progress : 1083/1399
# progress : 1084/1399
# progress : 1085/1399
# progress : 1086/1399
# progress : 1087/1399
# progress : 1088/1399
# progress : 1089/1399
# progress : 1090/1399
# progress : 1091/1399
# progress : 1092/1399
# progress : 1093/1399
# progress : 1094/1399
# progress : 1095/1399
# progress : 1096/1399
# progress : 1097/1399
# progress : 1098/1399
# progress : 1099/1399
# progress : 1100/1399
# progress : 1101/1399
# progress : 1102/1399
# progress : 1103/1399
# progress : 1104/1399
# progress : 1105/1399
# progress : 1106/1399
# progress : 1107/1399
# progress : 1108/1399
# progress : 1109/1399
# progress : 1110/1399
# progress : 1111/1399
# progress : 1112/1399
# progress : 1113/1399
# progress : 1114/1399
# progress : 1115/1399
# progress : 1116/1399
# progress : 1117/1399
# progress : 1118/1399
# progress : 1119/1399
# progress : 1120/1399
# progress : 1121/1399
# progress : 1122/1399
# progress : 1123/1399
# progress : 1124/1399
# progress : 1125/1399
# progress : 1126/1399
# progress : 1127/1399
# progress : 1128/1399
# progress : 1129/1399
# progress : 1130/1399
# progress : 1131/1399
# progress : 1132/1399
# progress : 1133/1399
# progress : 1134/1399
# progress : 1135/1399
# progress : 1136/1399
# progress : 1137/1399
# progress : 1138/1399
# progress : 1139/1399
# progress : 1140/1399
# progress : 1141/1399
# progress : 1142/1399
# progress : 1143/1399
# progress : 1144/1399
# progress : 1145/1399
# progress : 1146/1399
# progress : 1147/1399
# progress : 1148/1399
# progress : 1149/1399
# progress : 1150/1399
# progress : 1151/1399
# progress : 1152/1399
# progress : 1153/1399
# progress : 1154/1399
# progress : 1155/1399
# progress : 1156/1399
# progress : 1157/1399
# progress : 1158/1399
# progress : 1159/1399
# progress : 1160/1399
# progress : 1161/1399
# progress : 1162/1399
# progress : 1163/1399
# progress : 1164/1399
# progress : 1165/1399
# progress : 1166/1399
# progress : 1167/1399
# progress : 1168/1399
# progress : 1169/1399
# progress : 1170/1399
# progress : 1171/1399
# progress : 1172/1399
# progress : 1173/1399
# progress : 1174/1399
# progress : 1175/1399
# progress : 1176/1399
# progress : 1177/1399
# progress : 1178/1399
# progress : 1179/1399
# progress : 1180/1399
# progress : 1181/1399
# progress : 1182/1399
# progress : 1183/1399
# progress : 1184/1399
# progress : 1185/1399
# progress : 1186/1399
# progress : 1187/1399
# progress : 1188/1399
# progress : 1189/1399
# progress : 1190/1399
# progress : 1191/1399
# progress : 1192/1399
# progress : 1193/1399
# progress : 1194/1399
# progress : 1195/1399
# progress : 1196/1399
# progress : 1197/1399
# progress : 1198/1399
# progress : 1199/1399
# progress : 1200/1399
# progress : 1201/1399
# progress : 1202/1399
# progress : 1203/1399
# progress : 1204/1399
# progress : 1205/1399
# progress : 1206/1399
# progress : 1207/1399
# progress : 1208/1399
# progress : 1209/1399
# progress : 1210/1399
# progress : 1211/1399
# progress : 1212/1399
# progress : 1213/1399
# progress : 1214/1399
# progress : 1215/1399
# progress : 1216/1399
# progress : 1217/1399
# progress : 1218/1399
# progress : 1219/1399
# progress : 1220/1399
# progress : 1221/1399
# progress : 1222/1399
# progress : 1223/1399
# progress : 1224/1399
# progress : 1225/1399
# progress : 1226/1399
# progress : 1227/1399
# progress : 1228/1399
# progress : 1229/1399
# progress : 1230/1399
# progress : 1231/1399
# progress : 1232/1399
# progress : 1233/1399
# progress : 1234/1399
# progress : 1235/1399
# progress : 1236/1399
# progress : 1237/1399
# progress : 1238/1399
# progress : 1239/1399
# progress : 1240/1399
# progress : 1241/1399
# progress : 1242/1399
# progress : 1243/1399
# progress : 1244/1399
# progress : 1245/1399
# progress : 1246/1399
# progress : 1247/1399
# progress : 1248/1399
# progress : 1249/1399
# progress : 1250/1399
# progress : 1251/1399
# progress : 1252/1399
# progress : 1253/1399
# progress : 1254/1399
# progress : 1255/1399
# progress : 1256/1399
# progress : 1257/1399
# progress : 1258/1399
# progress : 1259/1399
# progress : 1260/1399
# progress : 1261/1399
# progress : 1262/1399
# progress : 1263/1399
# progress : 1264/1399
# progress : 1265/1399
# progress : 1266/1399
# progress : 1267/1399
# progress : 1268/1399
# progress : 1269/1399
# progress : 1270/1399
# progress : 1271/1399
# progress : 1272/1399
# progress : 1273/1399
# progress : 1274/1399
# progress : 1275/1399
# progress : 1276/1399
# progress : 1277/1399
# progress : 1278/1399
# progress : 1279/1399
# progress : 1280/1399
# progress : 1281/1399
# progress : 1282/1399
# progress : 1283/1399
# progress : 1284/1399
# progress : 1285/1399
# progress : 1286/1399
# progress : 1287/1399
# progress : 1288/1399
# progress : 1289/1399
# progress : 1290/1399
# progress : 1291/1399
# progress : 1292/1399
# progress : 1293/1399
# progress : 1294/1399
# progress : 1295/1399
# progress : 1296/1399
# progress : 1297/1399
# progress : 1298/1399
# progress : 1299/1399
# progress : 1300/1399
# progress : 1301/1399
# progress : 1302/1399
# progress : 1303/1399
# progress : 1304/1399
# progress : 1305/1399
# progress : 1306/1399
# progress : 1307/1399
# progress : 1308/1399
# progress : 1309/1399
# progress : 1310/1399
# progress : 1311/1399
# progress : 1312/1399
# progress : 1313/1399
# progress : 1314/1399
# progress : 1315/1399
# progress : 1316/1399
# progress : 1317/1399
# progress : 1318/1399
# progress : 1319/1399
# progress : 1320/1399
# progress : 1321/1399
# progress : 1322/1399
# progress : 1323/1399
# progress : 1324/1399
# progress : 1325/1399
# progress : 1326/1399
# progress : 1327/1399
# progress : 1328/1399
# progress : 1329/1399
# progress : 1330/1399
# progress : 1331/1399
# progress : 1332/1399
# progress : 1333/1399
# progress : 1334/1399
# progress : 1335/1399
# progress : 1336/1399
# progress : 1337/1399
# progress : 1338/1399
# progress : 1339/1399
# progress : 1340/1399
# progress : 1341/1399
# progress : 1342/1399
# progress : 1343/1399
# progress : 1344/1399
# progress : 1345/1399
# progress : 1346/1399
# progress : 1347/1399
# progress : 1348/1399
# progress : 1349/1399
# progress : 1350/1399
# progress : 1351/1399
# progress : 1352/1399
# progress : 1353/1399
# progress : 1354/1399
# progress : 1355/1399
# progress : 1356/1399
# progress : 1357/1399
# progress : 1358/1399
# progress : 1359/1399
# progress : 1360/1399
# progress : 1361/1399
# progress : 1362/1399
# progress : 1363/1399
# progress : 1364/1399
# progress : 1365/1399
# progress : 1366/1399
# progress : 1367/1399
# progress : 1368/1399
# progress : 1369/1399
# progress : 1370/1399
# progress : 1371/1399
# progress : 1372/1399
# progress : 1373/1399
# progress : 1374/1399
# progress : 1375/1399
# progress : 1376/1399
# progress : 1377/1399
# progress : 1378/1399
# progress : 1379/1399
# progress : 1380/1399
# progress : 1381/1399
# progress : 1382/1399
# progress : 1383/1399
# progress : 1384/1399
# progress : 1385/1399
# progress : 1386/1399
# progress : 1387/1399
# progress : 1388/1399
# progress : 1389/1399
# progress : 1390/1399
# progress : 1391/1399
# progress : 1392/1399
# progress : 1393/1399
# progress : 1394/1399
# progress : 1395/1399
# progress : 1396/1399
# progress : 1397/1399
# progress : 1398/1399
# Sum Fiat 5068658.092378421
# Sum Bitcoin 833.5002603099991
# Value Bitcoin 4101654.780985506
# Total Valuation 9170312.873363927
# Count Open 2078
# Sum Chartist Fiat 4126770.299359184
# Sum Chartist Bitcoin 650.0364125100004
# Value Chartist Bitcoin 3198829.185961712
# Total Chartist Valuation 7325599.485320896
# Count Chartist Open 1269
# Sum Chartist R1R1 Fiat 2070013.9223674287
# Sum Chartist R1R1 Bitcoin 113.19673719999996
# Value Chartist R1R1 Bitcoin 557041.1437611998
# Total Chartist R1R1 Valuation 2627055.0661286283
# Count Chartist R1R1 Open 133
# Sum Chartist R1R2 Fiat 789136.4767041338
# Sum Chartist R1R2 Bitcoin 260.0759575800002
# Value Chartist R1R2 Bitcoin 1279833.787251181
# Total Chartist R1R2 Valuation 2068970.2639553146
# Count Chartist R1R2 Open 426
# Sum Chartist R2R1 Fiat 1113161.7748354687
# Sum Chartist R2R1 Bitcoin 142.91015148999992
# Value Chartist R2R1 Bitcoin 703260.8554822896
# Total Chartist R2R1 Valuation 1816422.6303177583
# Count Chartist R2R1 Open 268
# Sum Chartist R2R2 Fiat 154458.12545215388
# Sum Chartist R2R2 Bitcoin 133.85356624000002
# Value Chartist R2R2 Bitcoin 658693.3994670401
# Total Chartist R2R2 Valuation 813151.5249191939
# Count Chartist R2R2 Open 442
# Sum Random Fiat 941887.7930192548
# Sum Random Bitcoin 183.46384779999988
# Value Random Bitcoin 902825.5950237995
# Total Random Valuation 1844713.3880430544
# Count Random Open 809
# NUMBER OF CHARTIST : 2550
# Chartist vs All Proportion Fiat : 81.41741313276736
# Chartist vs All Proportion Bitcoin : 77.98874739022109
# Chartist vs All Proportion Total Valuation : 79.88385550725121
# NUMBER OF CHARTIST R1R1 : 625
# Chartist R1R1 vs Chartist All Proportion Fiat : 50.160628583782966
# Chartist R1R1 vs Chartist All Proportion Bitcoin : 17.413907132203686
# Chartist R1R1 vs Chartist All Proportion Total Valuation : 35.86129806021672
# NUMBER OF CHARTIST R1R1 : 689
# Chartist R1R2 vs Chartist All Proportion Fiat : 19.12237462857269
# Chartist R1R2 vs Chartist All Proportion Bitcoin : 40.00944448261951
# Chartist R1R2 vs Chartist All Proportion Total Valuation : 28.243016398878158
# NUMBER OF CHARTIST R1R1 : 691
# Chartist R2R1 vs Chartist All Proportion Fiat : 26.97416367003328
# Chartist R2R1 vs Chartist All Proportion Bitcoin : 21.984945572229975
# Chartist R2R1 vs Chartist All Proportion Total Valuation : 24.7955492783563
# NUMBER OF CHARTIST R1R1 : 545
# Chartist R2R2 vs Chartist All Proportion Fiat : 3.7428331176110907
# Chartist R2R2 vs Chartist All Proportion Bitcoin : 20.591702812946767
# Chartist R2R2 vs Chartist All Proportion Total Valuation : 11.100136262548812
